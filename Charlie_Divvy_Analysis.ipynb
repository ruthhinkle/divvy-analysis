# %%
# Import Dependencies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd
import requests
import gmaps
import os

# Import API key
from api_keys import g_key

# %%
# Import data file
divvy_df = pd.read_csv('Divvy_Trips_2019_Q4.csv')
divvy_df.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  25223640  2019-10-01 00:01:39  2019-10-01 00:17:20    2215        940.0
# 1  25223641  2019-10-01 00:02:16  2019-10-01 00:06:34    6328        258.0
# 2  25223642  2019-10-01 00:04:32  2019-10-01 00:18:43    3003        850.0
# 3  25223643  2019-10-01 00:04:32  2019-10-01 00:43:43    3275      2,350.0
# 4  25223644  2019-10-01 00:04:34  2019-10-01 00:35:42    5294      1,867.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0               20    Sheffield Ave & Kingsbury St            309
# 1               19  Throop (Loomis) St & Taylor St            241
# 2               84       Milwaukee Ave & Grand Ave            199
# 3              313   Lakeview Ave & Fullerton Pkwy            290
# 4              210       Ashland Ave & Division St            382
#
#                to_station_name    usertype  gender  birthyear
# 0    Leavitt St & Armitage Ave  Subscriber    Male     1987.0
# 1          Morgan St & Polk St  Subscriber    Male     1998.0
# 2       Wabash Ave & Grand Ave  Subscriber  Female     1991.0
# 3       Kedzie Ave & Palmer Ct  Subscriber    Male     1990.0
# 4  Western Ave & Congress Pkwy  Subscriber    Male     1987.0

# %%
divvy_df.shape
# Out:
# (704054, 12)

# %%
# Remove null rows (if needed)
divvy_df.dropna()
divvy_df.shape
# Out:
# (704054, 12)

# %%
# Convert birthyear to age
divvy_df['age'] = (2021 - divvy_df['birthyear'])
divvy_df.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  25223640  2019-10-01 00:01:39  2019-10-01 00:17:20    2215        940.0
# 1  25223641  2019-10-01 00:02:16  2019-10-01 00:06:34    6328        258.0
# 2  25223642  2019-10-01 00:04:32  2019-10-01 00:18:43    3003        850.0
# 3  25223643  2019-10-01 00:04:32  2019-10-01 00:43:43    3275      2,350.0
# 4  25223644  2019-10-01 00:04:34  2019-10-01 00:35:42    5294      1,867.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0               20    Sheffield Ave & Kingsbury St            309
# 1               19  Throop (Loomis) St & Taylor St            241
# 2               84       Milwaukee Ave & Grand Ave            199
# 3              313   Lakeview Ave & Fullerton Pkwy            290
# 4              210       Ashland Ave & Division St            382
#
#                to_station_name    usertype  gender  birthyear   age
# 0    Leavitt St & Armitage Ave  Subscriber    Male     1987.0  34.0
# 1          Morgan St & Polk St  Subscriber    Male     1998.0  23.0
# 2       Wabash Ave & Grand Ave  Subscriber  Female     1991.0  30.0
# 3       Kedzie Ave & Palmer Ct  Subscriber    Male     1990.0  31.0
# 4  Western Ave & Congress Pkwy  Subscriber    Male     1987.0  34.0

# %%
# Create bins for age
bins = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# Create the names for the five bins
group_names = ["11-19", "20-29", "30-39", "40-49", "50-59", "60-69", "70-79", "80-89"]
divvy_df["Age Group"] = pd.cut(divvy_df["age"], bins, labels=group_names, include_lowest=True)
divvy_df.head()
# Out:
#     trip_id           start_time             end_time  bikeid tripduration  \
# 0  25223640  2019-10-01 00:01:39  2019-10-01 00:17:20    2215        940.0
# 1  25223641  2019-10-01 00:02:16  2019-10-01 00:06:34    6328        258.0
# 2  25223642  2019-10-01 00:04:32  2019-10-01 00:18:43    3003        850.0
# 3  25223643  2019-10-01 00:04:32  2019-10-01 00:43:43    3275      2,350.0
# 4  25223644  2019-10-01 00:04:34  2019-10-01 00:35:42    5294      1,867.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0               20    Sheffield Ave & Kingsbury St            309
# 1               19  Throop (Loomis) St & Taylor St            241
# 2               84       Milwaukee Ave & Grand Ave            199
# 3              313   Lakeview Ave & Fullerton Pkwy            290
# 4              210       Ashland Ave & Division St            382
#
#                to_station_name    usertype  gender  birthyear   age Age Group
# 0    Leavitt St & Armitage Ave  Subscriber    Male     1987.0  34.0     30-39
# 1          Morgan St & Polk St  Subscriber    Male     1998.0  23.0     20-29
# 2       Wabash Ave & Grand Ave  Subscriber  Female     1991.0  30.0     20-29
# 3       Kedzie Ave & Palmer Ct  Subscriber    Male     1990.0  31.0     30-39
# 4  Western Ave & Congress Pkwy  Subscriber    Male     1987.0  34.0     30-39

# %%
#Review bins
divvy_df['Age Group'].value_counts()
# Out:
# 30-39    243138
# 20-29    207020
# 40-49     93019
# 50-59     65825
# 60-69     26771
# 11-19      3945
# 70-79      2279
# 80-89        82
# Name: Age Group, dtype: int64

# %%
# Plot bins as bar graph

# %%
# Convert date columns to datetime format
divvy_df['start_time'] = pd.to_datetime(divvy_df['start_time'])
divvy_df['end_time'] = pd.to_datetime(divvy_df['end_time'])

# %%
# Split date from time and create columns
divvy_df['start_date'] = divvy_df['start_time'].dt.date
divvy_df['start_time'] = divvy_df['start_time'].dt.time
divvy_df['end_date'] = divvy_df['end_time'].dt.date
divvy_df['end_time'] = divvy_df['end_time'].dt.time
divvy_df.head()
# Out:
#     trip_id start_time  end_time  bikeid tripduration  from_station_id  \
# 0  25223640   00:01:39  00:17:20    2215        940.0               20
# 1  25223641   00:02:16  00:06:34    6328        258.0               19
# 2  25223642   00:04:32  00:18:43    3003        850.0               84
# 3  25223643   00:04:32  00:43:43    3275      2,350.0              313
# 4  25223644   00:04:34  00:35:42    5294      1,867.0              210
#
#                 from_station_name  to_station_id              to_station_name  \
# 0    Sheffield Ave & Kingsbury St            309    Leavitt St & Armitage Ave
# 1  Throop (Loomis) St & Taylor St            241          Morgan St & Polk St
# 2       Milwaukee Ave & Grand Ave            199       Wabash Ave & Grand Ave
# 3   Lakeview Ave & Fullerton Pkwy            290       Kedzie Ave & Palmer Ct
# 4       Ashland Ave & Division St            382  Western Ave & Congress Pkwy
#
#      usertype  gender  birthyear   age Age Group  start_date    end_date
# 0  Subscriber    Male     1987.0  34.0     30-39  2019-10-01  2019-10-01
# 1  Subscriber    Male     1998.0  23.0     20-29  2019-10-01  2019-10-01
# 2  Subscriber  Female     1991.0  30.0     20-29  2019-10-01  2019-10-01
# 3  Subscriber    Male     1990.0  31.0     30-39  2019-10-01  2019-10-01
# 4  Subscriber    Male     1987.0  34.0     30-39  2019-10-01  2019-10-01

# %%
# Organize columns in dataframe
divvy_df = divvy_df[["trip_id", "bikeid", "start_date", "start_time", "end_date", "end_time", "tripduration", "from_station_id", "from_station_name", "to_station_id", "to_station_name", "usertype", "gender", "birthyear", "age", "Age Group"]]
divvy_df.head()
# Out:
#     trip_id  bikeid  start_date start_time    end_date  end_time tripduration  \
# 0  25223640    2215  2019-10-01   00:01:39  2019-10-01  00:17:20        940.0
# 1  25223641    6328  2019-10-01   00:02:16  2019-10-01  00:06:34        258.0
# 2  25223642    3003  2019-10-01   00:04:32  2019-10-01  00:18:43        850.0
# 3  25223643    3275  2019-10-01   00:04:32  2019-10-01  00:43:43      2,350.0
# 4  25223644    5294  2019-10-01   00:04:34  2019-10-01  00:35:42      1,867.0
#
#    from_station_id               from_station_name  to_station_id  \
# 0               20    Sheffield Ave & Kingsbury St            309
# 1               19  Throop (Loomis) St & Taylor St            241
# 2               84       Milwaukee Ave & Grand Ave            199
# 3              313   Lakeview Ave & Fullerton Pkwy            290
# 4              210       Ashland Ave & Division St            382
#
#                to_station_name    usertype  gender  birthyear   age Age Group
# 0    Leavitt St & Armitage Ave  Subscriber    Male     1987.0  34.0     30-39
# 1          Morgan St & Polk St  Subscriber    Male     1998.0  23.0     20-29
# 2       Wabash Ave & Grand Ave  Subscriber  Female     1991.0  30.0     20-29
# 3       Kedzie Ave & Palmer Ct  Subscriber    Male     1990.0  31.0     30-39
# 4  Western Ave & Congress Pkwy  Subscriber    Male     1987.0  34.0     30-39

# %%
# Number of unique bikes in circulation
divvy_df['bikeid'].nunique()
# Out:
# 5670

# %%
# Bike IDs with most activity

divvy_df['bikeid'].value_counts()
# Out:
# 5886    283
# 4832    273
# 1889    270
# 4848    267
# 1100    266
#        ...
# 805       1
# 3909      1
# 2985      1
# 6710      1
# 786       1
# Name: bikeid, Length: 5670, dtype: int64

# %%
# Most popular starting stations
divvy_df['from_station_name'].value_counts()
# Out:
# Canal St & Adams St                     12937
# Clinton St & Madison St                 10580
# Clinton St & Washington Blvd             9834
# Columbus Dr & Randolph St                7723
# Kingsbury St & Kinzie St                 7326
#                                         ...
# Stony Island Ave & South Chicago Ave        2
# Seeley Ave & Garfield Blvd                  1
# Carpenter St & 63rd St                      1
# Elizabeth St & 59th St                      1
# Ashland Ave & 66th St                       1
# Name: from_station_name, Length: 610, dtype: int64

# %%
# Most popular ending stations

divvy_df['to_station_name'].value_counts()
# Out:
# Canal St & Adams St               12812
# Clinton St & Washington Blvd      11051
# Clinton St & Madison St           10360
# Streeter Dr & Grand Ave            8820
# Kingsbury St & Kinzie St           7172
#                                   ...
# Halsted St & 51st St                  3
# Seeley Ave & Garfield Blvd            2
# South Chicago Ave & 83rd St           2
# Elizabeth St & 59th St                2
# South Chicago Ave & Elliot Ave        1
# Name: to_station_name, Length: 608, dtype: int64

# %%
# Most popular trips *still in-progress*
popular_stations = divvy_df.groupby(['from_station_name','to_station_name'])
popular_stations.head()
# Out:
#          trip_id  bikeid  start_date start_time    end_date  end_time  \
# 0       25223640    2215  2019-10-01   00:01:39  2019-10-01  00:17:20
# 1       25223641    6328  2019-10-01   00:02:16  2019-10-01  00:06:34
# 2       25223642    3003  2019-10-01   00:04:32  2019-10-01  00:18:43
# 3       25223643    3275  2019-10-01   00:04:32  2019-10-01  00:43:43
# 4       25223644    5294  2019-10-01   00:04:34  2019-10-01  00:35:42
# ...          ...     ...         ...        ...         ...       ...
# 704013  25962861    6013  2019-12-31   23:19:28  2019-12-31  23:32:05
# 704014  25962862    5474  2019-12-31   23:21:40  2019-12-31  23:37:53
# 704015  25962863    4455  2019-12-31   23:23:54  2019-12-31  23:52:32
# 704020  25962868    3939  2019-12-31   23:27:24  2020-01-01  17:25:25
# 704029  25962878    3775  2019-12-31   23:35:28  2019-12-31  23:40:59
#
#        tripduration  from_station_id               from_station_name  \
# 0             940.0               20    Sheffield Ave & Kingsbury St
# 1             258.0               19  Throop (Loomis) St & Taylor St
# 2             850.0               84       Milwaukee Ave & Grand Ave
# 3           2,350.0              313   Lakeview Ave & Fullerton Pkwy
# 4           1,867.0              210       Ashland Ave & Division St
# ...             ...              ...                             ...
# 704013        757.0              169          Canal St & Harrison St
# 704014        973.0              146        Loomis St & Jackson Blvd
# 704015      1,718.0              112          Green St & Randolph St
# 704020     64,681.0              127     Lincoln Ave & Fullerton Ave
# 704029        330.0              160        Campbell Ave & North Ave
#
#         to_station_id                         to_station_name    usertype  \
# 0                 309               Leavitt St & Armitage Ave  Subscriber
# 1                 241                     Morgan St & Polk St  Subscriber
# 2                 199                  Wabash Ave & Grand Ave  Subscriber
# 3                 290                  Kedzie Ave & Palmer Ct  Subscriber
# 4                 382             Western Ave & Congress Pkwy  Subscriber
# ...               ...                                     ...         ...
# 704013            132          Wentworth Ave & 24th St (Temp)  Subscriber
# 704014            382             Western Ave & Congress Pkwy  Subscriber
# 704015            207                   Emerald Ave & 28th St  Subscriber
# 704020            671  HUBBARD ST BIKE CHECKING (LBS-WH-TEST)    Customer
# 704029            309               Leavitt St & Armitage Ave  Subscriber
#
#         gender  birthyear   age Age Group
# 0         Male     1987.0  34.0     30-39
# 1         Male     1998.0  23.0     20-29
# 2       Female     1991.0  30.0     20-29
# 3         Male     1990.0  31.0     30-39
# 4         Male     1987.0  34.0     30-39
# ...        ...        ...   ...       ...
# 704013    Male     1982.0  39.0     30-39
# 704014     NaN     1999.0  22.0     20-29
# 704015    Male     1980.0  41.0     40-49
# 704020    Male     1995.0  26.0     20-29
# 704029    Male     1991.0  30.0     20-29
#
# [209034 rows x 16 columns]

# %%
popular_from_stations = divvy_df['from_station_name'].value_counts()

popular_from_stations.head(10)
# Out:
# Canal St & Adams St             12937
# Clinton St & Madison St         10580
# Clinton St & Washington Blvd     9834
# Columbus Dr & Randolph St        7723
# Kingsbury St & Kinzie St         7326
# Franklin St & Monroe St          6838
# Streeter Dr & Grand Ave          6774
# Daley Center Plaza               6166
# Michigan Ave & Washington St     6077
# Lake Shore Dr & Monroe St        5960
# Name: from_station_name, dtype: int64

# %%
station_list = divvy_df.loc[(divvy_df['from_station_id'] == 192) \
                            | (divvy_df['from_station_id'] == 77) \
                            | (divvy_df['from_station_id'] == 91)]

station_list
# Out:
#          trip_id  bikeid  start_date start_time    end_date  end_time  \
# 10      25223650    2564  2019-10-01   00:05:30  2019-10-01  00:37:36
# 221     25223866    3559  2019-10-01   05:16:38  2019-10-01  05:22:41
# 225     25223872    6255  2019-10-01   05:18:35  2019-10-01  05:31:34
# 252     25223901     944  2019-10-01   05:27:32  2019-10-01  05:42:42
# 425     25224079    2117  2019-10-01   06:01:31  2019-10-01  06:07:41
# ...          ...     ...         ...        ...         ...       ...
# 703857  25962694    5307  2019-12-31   19:37:36  2019-12-31  19:50:12
# 703960  25962806    1511  2019-12-31   21:47:02  2019-12-31  22:14:39
# 703961  25962807    1589  2019-12-31   21:47:05  2019-12-31  22:14:44
# 703962  25962808    1736  2019-12-31   21:47:09  2019-12-31  22:14:44
# 703963  25962809    5127  2019-12-31   21:47:15  2019-12-31  22:14:43
#
#        tripduration  from_station_id             from_station_name  \
# 10          1,925.0               77       Clinton St & Madison St
# 221           362.0              192           Canal St & Adams St
# 225           779.0              192           Canal St & Adams St
# 252           910.0               91  Clinton St & Washington Blvd
# 425           370.0               77       Clinton St & Madison St
# ...             ...              ...                           ...
# 703857        755.0               77       Clinton St & Madison St
# 703960      1,656.0              192           Canal St & Adams St
# 703961      1,659.0              192           Canal St & Adams St
# 703962      1,655.0              192           Canal St & Adams St
# 703963      1,648.0              192           Canal St & Adams St
#
#         to_station_id                to_station_name    usertype gender  \
# 10                506   Spaulding Ave & Armitage Ave  Subscriber   Male
# 221               284    Michigan Ave & Jackson Blvd  Subscriber   Male
# 225               142           McClurg Ct & Erie St  Subscriber   Male
# 252               211         St. Clair St & Erie St  Subscriber   Male
# 425                89  Financial Pl & Ida B Wells Dr  Subscriber   Male
# ...               ...                            ...         ...    ...
# 703857            337         Clark St & Chicago Ave  Subscriber   Male
# 703960              6                 Dusable Harbor    Customer   Male
# 703961              6                 Dusable Harbor    Customer   Male
# 703962              6                 Dusable Harbor    Customer   Male
# 703963              6                 Dusable Harbor    Customer   Male
#
#         birthyear   age Age Group
# 10         1977.0  44.0     40-49
# 221        1969.0  52.0     50-59
# 225        1967.0  54.0     50-59
# 252        1960.0  61.0     60-69
# 425        1948.0  73.0     70-79
# ...           ...   ...       ...
# 703857     1988.0  33.0     30-39
# 703960     2002.0  19.0     11-19
# 703961     2002.0  19.0     11-19
# 703962     2002.0  19.0     11-19
# 703963     2002.0  19.0     11-19
#
# [33351 rows x 16 columns]

# %%
# Groupby usertype for ridership breakdown

usertype_df = divvy_df.groupby('usertype')
usertype_df.count()
# Out:
#             trip_id  start_time  end_time  bikeid  tripduration  \
# usertype
# Customer     106194      106194    106194  106194        106194
# Subscriber   597860      597860    597860  597860        597860
#
#             from_station_id  from_station_name  to_station_id  \
# usertype
# Customer             106194             106194         106194
# Subscriber           597860             597860         597860
#
#             to_station_name  gender  birthyear
# usertype
# Customer             106194   44658      45265
# Subscriber           597860  592805     597108

# %%
# Create calculation for average trip duration

# %%
# Summary statistics by each user type:
# - Gender %
# - Age groups and bins for histogram
# - Average trip duration
